# %% [markdown]
# ### Stay at Home State Mandates
#
# source: [The Henry J. Kaiser Family Foundation](https://www.kff.org/health-costs/issue-brief/state-data-and-policy-actions-to-address-coronavirus/)
#
# Data: up to date ending with April 29, 2020
#
# Included:
#
#  *  state mandates issued by the state's executive branch (if legislative mandates exist, the data set does not contain information about those)
#  * many states have recommendations in place, however, in this dataset only states that issued restricting orders were taken into consideration
#
# >FOOTNOTES from the original data source
# >1. CT, RI, and WV have prohibited gatherings larger than five people, with limited exceptions.
# 2. Social distancing restrictions remain in place in three counties in South FL, where reopening decisions are under the jurisdiction of local leadership.
# 3. The FL governor has prohibited gatherings of more than 10 people in public spaces, but limits on private gatherings have fallen short of a mandate.
# 4. Social distancing restrictions remain in place in three counties.
# 5. Non-essential businesses remain closed and restaurants remain closed to dine-in services in some hard-hit counties
# 6. Iowa bans all gatherings in 14 hard-hit counties in the northeastern part of the state, and bans gatherings of more than 10 people in the rest of the state.
# 7. NE has enacted a large gatherings ban and bar/restaurant limits in counties where community spread has been confirmed.
# 8. Nebraska has implemented less restrictive orders allowing restaurants to re-open with capacity limits in 10 of its 19 local health districts.
# 9. Judge has ordered NY to hold its primary election, but litigation is still ongoing.
# 10. Tennessee has implemented less restrictive orders allowing non-essential businesses and restaurants to reopen in 89 of the state’s 95 counties.
# 11. Gatherings also limited to 50% of venue capacity if such limitation would be under 50 people.
# ---

# %%
import pandas as pd

# %%
data = pd.read_csv('../data/state_mandates.csv')

# %%
df.head(15)
# Out:
#                      State Is Easing Social Distancing Measures  \
# Location
# United States                                 Yes (26); No (25)
# Alabama                                                     Yes
# Alaska                                                      Yes
# Arizona                                                     NaN
# Arkansas                                                    NaN
# California                                                  NaN
# Colorado                                                    Yes
# Connecticut                                                 NaN
# Delaware                                                    NaN
# District of Columbia                                        NaN
# Florida                                                     Yes
# Georgia                                                     Yes
# Hawaii                                                      Yes
# Idaho                                                       Yes
# Illinois                                                    NaN
#
#                                                      Stay at Home Order  \
# Location
# United States         Original Stay at Home Order in Place (29); Sta...
# Alabama                                                          Lifted
# Alaska                                                           Lifted
# Arizona                                                       Statewide
# Arkansas                                                            NaN
# California                                                    Statewide
# Colorado                                Rolled Back to High Risk Groups
# Connecticut                                                   Statewide
# Delaware                                                      Statewide
# District of Columbia                                          Statewide
# Florida                                                          Lifted
# Georgia                                 Rolled Back to High Risk Groups
# Hawaii                                                        Statewide
# Idaho                                                            Lifted
# Illinois                                                      Statewide
#
#                                      Mandatory Quarantine for Travelers  \
# Location
# United States         Original Traveler Quarantine Mandate in Place ...
# Alabama                                                             NaN
# Alaska                                                    All Travelers
# Arizona                                             From Certain States
# Arkansas                                                            NaN
# California                                                          NaN
# Colorado                                                            NaN
# Connecticut                                                         NaN
# Delaware                                                  All Travelers
# District of Columbia                                                NaN
# Florida                                             From Certain States
# Georgia                                                             NaN
# Hawaii                                                    All Travelers
# Idaho                                                     All Travelers
# Illinois                                                            NaN
#
#                                         Non-Essential Business Closures  \
# Location
# United States         Original Non-Essential Business Closures Still...
# Alabama               Some Non-Essential Businesses Permitted to Reo...
# Alaska                Some Non-Essential Businesses Permitted to Reo...
# Arizona                             All Non-Essential Businesses Closed
# Arkansas                                                            NaN
# California                          All Non-Essential Businesses Closed
# Colorado              Some Non-Essential Businesses Permitted to Reo...
# Connecticut                         All Non-Essential Businesses Closed
# Delaware                            All Non-Essential Businesses Closed
# District of Columbia                All Non-Essential Businesses Closed
# Florida               Some Non-Essential Businesses Permitted to Reo...
# Georgia               Some Non-Essential Businesses Permitted to Reo...
# Hawaii                Some Non-Essential Businesses Permitted to Reopen
# Idaho                 Some Non-Essential Businesses Permitted to Reopen
# Illinois                            All Non-Essential Businesses Closed
#
#                                                    Large Gatherings Ban  \
# Location
# United States         Original Gathering Ban/Limit in Place (40); Ga...
# Alabama                                           >10 People Prohibited
# Alaska                                Expanded to 20+ People Prohibited
# Arizona                                           >10 People Prohibited
# Arkansas                                          >10 People Prohibited
# California                                    All Gatherings Prohibited
# Colorado                              Expanded to >10 People Prohibited
# Connecticut                                                       Other
# Delaware                                          >10 People Prohibited
# District of Columbia                              >10 People Prohibited
# Florida                                                           Other
# Georgia                                           >10 People Prohibited
# Hawaii                                            >10 People Prohibited
# Idaho                                                            Lifted
# Illinois                                      All Gatherings Prohibited
#
#                                                         School Closures  \
# Location
# United States         Closed (7); Closed for School Year (36); Recom...
# Alabama                                          Closed for School Year
# Alaska                                           Closed for School Year
# Arizona                                          Closed for School Year
# Arkansas                                         Closed for School Year
# California                          Recommended Closure for School Year
# Colorado                                         Closed for School Year
# Connecticut                                      Closed for School Year
# Delaware                                         Closed for School Year
# District of Columbia                             Closed for School Year
# Florida                             Recommended Closure for School Year
# Georgia                                          Closed for School Year
# Hawaii                                           Closed for School Year
# Idaho                                               Recommended Closure
# Illinois                                         Closed for School Year
#
#                                                       Restaurant Limits  \
# Location
# United States         Original Restaurant Closures Still in Place (3...
# Alabama                              Closed Except for Takeout/Delivery
# Alaska                 Reopened to Dine-in Service with Capacity Limits
# Arizona                              Closed Except for Takeout/Delivery
# Arkansas                             Closed Except for Takeout/Delivery
# California                           Closed Except for Takeout/Delivery
# Colorado                             Closed Except for Takeout/Delivery
# Connecticut                          Closed Except for Takeout/Delivery
# Delaware                             Closed Except for Takeout/Delivery
# District of Columbia                 Closed Except for Takeout/Delivery
# Florida                Reopened to Dine-in Service with Capacity Limits
# Georgia                Reopened to Dine-in Service with Capacity Limits
# Hawaii                               Closed Except for Takeout/Delivery
# Idaho                                Closed Except for Takeout/Delivery
# Illinois                             Closed Except for Takeout/Delivery
#
#                               Primary Election Postponement  \
# Location
# United States         Postponed (14); Canceled (1); No (36)
# Alabama                                                 NaN
# Alaska                                                  NaN
# Arizona                                                 NaN
# Arkansas                                                NaN
# California                                              NaN
# Colorado                                                NaN
# Connecticut                                       Postponed
# Delaware                                          Postponed
# District of Columbia                                    NaN
# Florida                                                 NaN
# Georgia                                           Postponed
# Hawaii                                                  NaN
# Idaho                                                   NaN
# Illinois                                                NaN
#
#                      Emergency Declaration Footnotes
# Location
# United States             Yes (51); No (0)       NaN
# Alabama                                Yes       NaN
# Alaska                                 Yes       NaN
# Arizona                                Yes       NaN
# Arkansas                               Yes       NaN
# California                             Yes       NaN
# Colorado                               Yes       NaN
# Connecticut                            Yes         1
# Delaware                               Yes       NaN
# District of Columbia                   Yes       NaN
# Florida                                Yes      2, 3
# Georgia                                Yes       NaN
# Hawaii                                 Yes       NaN
# Idaho                                  Yes       NaN
# Illinois                               Yes       NaN

# %%
df = df.iloc[0:52, :]

# %%
df.tail(5)
# Out:
#               State Is Easing Social Distancing Measures Stay at Home Order  \
# Location
# Virginia                                             NaN          Statewide
# Washington                                           NaN          Statewide
# West Virginia                                        Yes             Lifted
# Wisconsin                                            NaN          Statewide
# Wyoming                                              NaN                NaN
#
#               Mandatory Quarantine for Travelers  \
# Location
# Virginia                                     NaN
# Washington                                   NaN
# West Virginia                From Certain States
# Wisconsin                                    NaN
# Wyoming                            All Travelers
#
#                                  Non-Essential Business Closures  \
# Location
# Virginia                    Some Non-Essential Businesses Closed
# Washington                   All Non-Essential Businesses Closed
# West Virginia  Some Non-Essential Businesses Permitted to Reo...
# Wisconsin                    All Non-Essential Businesses Closed
# Wyoming                                                      NaN
#
#                             Large Gatherings Ban         School Closures  \
# Location
# Virginia                   >10 People Prohibited  Closed for School Year
# Washington             All Gatherings Prohibited  Closed for School Year
# West Virginia  Expanded to 25+ People Prohibited  Closed for School Year
# Wisconsin              All Gatherings Prohibited  Closed for School Year
# Wyoming                    >10 People Prohibited                  Closed
#
#                                               Restaurant Limits  \
# Location
# Virginia                     Closed Except for Takeout/Delivery
# Washington                   Closed Except for Takeout/Delivery
# West Virginia  Reopened to Dine-in Service with Capacity Limits
# Wisconsin                    Closed Except for Takeout/Delivery
# Wyoming                      Closed Except for Takeout/Delivery
#
#               Primary Election Postponement Emergency Declaration Footnotes
# Location
# Virginia                                NaN                   Yes       NaN
# Washington                              NaN                   Yes       NaN
# West Virginia                     Postponed                   Yes         1
# Wisconsin                               NaN                   Yes       NaN
# Wyoming                                 NaN                   Yes       NaN

# %%
# export data to csv

df.to_csv('../data/state_mandates.csv', index=True)

# %%
data = pd.read_csv('../data/state_mandates.csv')

# %%
data.shape
# Out:
# (52, 11)
