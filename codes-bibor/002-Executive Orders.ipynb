# %% [markdown]
# ### Stay at Home State Mandates
#
# source: [The Henry J. Kaiser Family Foundation](https://www.kff.org/health-costs/issue-brief/state-data-and-policy-actions-to-address-coronavirus/)
#
# Data: up to date ending with April 29, 2020
#
# Included:
#
#  *  state mandates issued by the state's executive branch (if legislative mandates exist, the data set does not contain information about those)
#  * many states have recommendations in place, however, in this dataset only states that issued restricting orders were taken into consideration
#
# >FOOTNOTES from the original data source
# >1. CT, RI, and WV have prohibited gatherings larger than five people, with limited exceptions.
# 2. Social distancing restrictions remain in place in three counties in South FL, where reopening decisions are under the jurisdiction of local leadership.
# 3. The FL governor has prohibited gatherings of more than 10 people in public spaces, but limits on private gatherings have fallen short of a mandate.
# 4. Social distancing restrictions remain in place in three counties.
# 5. Non-essential businesses remain closed and restaurants remain closed to dine-in services in some hard-hit counties
# 6. Iowa bans all gatherings in 14 hard-hit counties in the northeastern part of the state, and bans gatherings of more than 10 people in the rest of the state.
# 7. NE has enacted a large gatherings ban and bar/restaurant limits in counties where community spread has been confirmed.
# 8. Nebraska has implemented less restrictive orders allowing restaurants to re-open with capacity limits in 10 of its 19 local health districts.
# 9. Judge has ordered NY to hold its primary election, but litigation is still ongoing.
# 10. Tennessee has implemented less restrictive orders allowing non-essential businesses and restaurants to reopen in 89 of the state’s 95 counties.
# 11. Gatherings also limited to 50% of venue capacity if such limitation would be under 50 people.
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/state_mandates.csv')

# %%
df.head(15)
# Out:
#                 Location State Is Easing Social Distancing Measures  \
# 0          United States                          Yes (26); No (25)
# 1                Alabama                                        Yes
# 2                 Alaska                                        Yes
# 3                Arizona                                        NaN
# 4               Arkansas                                        NaN
# 5             California                                        NaN
# 6               Colorado                                        Yes
# 7            Connecticut                                        NaN
# 8               Delaware                                        NaN
# 9   District of Columbia                                        NaN
# 10               Florida                                        Yes
# 11               Georgia                                        Yes
# 12                Hawaii                                        Yes
# 13                 Idaho                                        Yes
# 14              Illinois                                        NaN
#
#                                    Stay at Home Order  \
# 0   Original Stay at Home Order in Place (29); Sta...
# 1                                              Lifted
# 2                                              Lifted
# 3                                           Statewide
# 4                                                 NaN
# 5                                           Statewide
# 6                     Rolled Back to High Risk Groups
# 7                                           Statewide
# 8                                           Statewide
# 9                                           Statewide
# 10                                             Lifted
# 11                    Rolled Back to High Risk Groups
# 12                                          Statewide
# 13                                             Lifted
# 14                                          Statewide
#
#                    Mandatory Quarantine for Travelers  \
# 0   Original Traveler Quarantine Mandate in Place ...
# 1                                                 NaN
# 2                                       All Travelers
# 3                                 From Certain States
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                       All Travelers
# 9                                                 NaN
# 10                                From Certain States
# 11                                                NaN
# 12                                      All Travelers
# 13                                      All Travelers
# 14                                                NaN
#
#                       Non-Essential Business Closures  \
# 0   Original Non-Essential Business Closures Still...
# 1   Some Non-Essential Businesses Permitted to Reo...
# 2   Some Non-Essential Businesses Permitted to Reo...
# 3                 All Non-Essential Businesses Closed
# 4                                                 NaN
# 5                 All Non-Essential Businesses Closed
# 6   Some Non-Essential Businesses Permitted to Reo...
# 7                 All Non-Essential Businesses Closed
# 8                 All Non-Essential Businesses Closed
# 9                 All Non-Essential Businesses Closed
# 10  Some Non-Essential Businesses Permitted to Reo...
# 11  Some Non-Essential Businesses Permitted to Reo...
# 12  Some Non-Essential Businesses Permitted to Reopen
# 13  Some Non-Essential Businesses Permitted to Reopen
# 14                All Non-Essential Businesses Closed
#
#                                  Large Gatherings Ban  \
# 0   Original Gathering Ban/Limit in Place (40); Ga...
# 1                               >10 People Prohibited
# 2                   Expanded to 20+ People Prohibited
# 3                               >10 People Prohibited
# 4                               >10 People Prohibited
# 5                           All Gatherings Prohibited
# 6                   Expanded to >10 People Prohibited
# 7                                               Other
# 8                               >10 People Prohibited
# 9                               >10 People Prohibited
# 10                                              Other
# 11                              >10 People Prohibited
# 12                              >10 People Prohibited
# 13                                             Lifted
# 14                          All Gatherings Prohibited
#
#                                       School Closures  \
# 0   Closed (7); Closed for School Year (36); Recom...
# 1                              Closed for School Year
# 2                              Closed for School Year
# 3                              Closed for School Year
# 4                              Closed for School Year
# 5                 Recommended Closure for School Year
# 6                              Closed for School Year
# 7                              Closed for School Year
# 8                              Closed for School Year
# 9                              Closed for School Year
# 10                Recommended Closure for School Year
# 11                             Closed for School Year
# 12                             Closed for School Year
# 13                                Recommended Closure
# 14                             Closed for School Year
#
#                                     Restaurant Limits  \
# 0   Original Restaurant Closures Still in Place (3...
# 1                  Closed Except for Takeout/Delivery
# 2    Reopened to Dine-in Service with Capacity Limits
# 3                  Closed Except for Takeout/Delivery
# 4                  Closed Except for Takeout/Delivery
# 5                  Closed Except for Takeout/Delivery
# 6                  Closed Except for Takeout/Delivery
# 7                  Closed Except for Takeout/Delivery
# 8                  Closed Except for Takeout/Delivery
# 9                  Closed Except for Takeout/Delivery
# 10   Reopened to Dine-in Service with Capacity Limits
# 11   Reopened to Dine-in Service with Capacity Limits
# 12                 Closed Except for Takeout/Delivery
# 13                 Closed Except for Takeout/Delivery
# 14                 Closed Except for Takeout/Delivery
#
#             Primary Election Postponement Emergency Declaration Footnotes
# 0   Postponed (14); Canceled (1); No (36)      Yes (51); No (0)       NaN
# 1                                     NaN                   Yes       NaN
# 2                                     NaN                   Yes       NaN
# 3                                     NaN                   Yes       NaN
# 4                                     NaN                   Yes       NaN
# 5                                     NaN                   Yes       NaN
# 6                                     NaN                   Yes       NaN
# 7                               Postponed                   Yes         1
# 8                               Postponed                   Yes       NaN
# 9                                     NaN                   Yes       NaN
# 10                                    NaN                   Yes      2, 3
# 11                              Postponed                   Yes       NaN
# 12                                    NaN                   Yes       NaN
# 13                                    NaN                   Yes       NaN
# 14                                    NaN                   Yes       NaN

# %%
df.tail()
# Out:
#          Location State Is Easing Social Distancing Measures  \
# 47       Virginia                                        NaN
# 48     Washington                                        NaN
# 49  West Virginia                                        Yes
# 50      Wisconsin                                        NaN
# 51        Wyoming                                        NaN
#
#    Stay at Home Order Mandatory Quarantine for Travelers  \
# 47          Statewide                                NaN
# 48          Statewide                                NaN
# 49             Lifted                From Certain States
# 50          Statewide                                NaN
# 51                NaN                      All Travelers
#
#                       Non-Essential Business Closures  \
# 47               Some Non-Essential Businesses Closed
# 48                All Non-Essential Businesses Closed
# 49  Some Non-Essential Businesses Permitted to Reo...
# 50                All Non-Essential Businesses Closed
# 51                                                NaN
#
#                  Large Gatherings Ban         School Closures  \
# 47              >10 People Prohibited  Closed for School Year
# 48          All Gatherings Prohibited  Closed for School Year
# 49  Expanded to 25+ People Prohibited  Closed for School Year
# 50          All Gatherings Prohibited  Closed for School Year
# 51              >10 People Prohibited                  Closed
#
#                                    Restaurant Limits  \
# 47                Closed Except for Takeout/Delivery
# 48                Closed Except for Takeout/Delivery
# 49  Reopened to Dine-in Service with Capacity Limits
# 50                Closed Except for Takeout/Delivery
# 51                Closed Except for Takeout/Delivery
#
#    Primary Election Postponement Emergency Declaration Footnotes
# 47                           NaN                   Yes       NaN
# 48                           NaN                   Yes       NaN
# 49                     Postponed                   Yes         1
# 50                           NaN                   Yes       NaN
# 51                           NaN                   Yes       NaN

# %%
data.shape
# Out:
# (52, 11)
