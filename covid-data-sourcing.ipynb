# %%
import requests
import pandas as pd

# %%
url = 'https://covidtracking.com/api/v1/states/daily.json'

# %%
req = requests.get(url)
req.status_code
# Out:
# 200

# %%
covid = req.json()

# %%
covid = pd.DataFrame(covid)

# %%
covid.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200506    AK     372.0   23283.0      NaN                    8.0
# 1  20200506    AL    8581.0  100935.0      NaN                    NaN
# 2  20200506    AR    3568.0   55435.0      NaN                   69.0
# 3  20200506    AS       0.0      83.0      NaN                    NaN
# 4  20200506    AZ    9707.0   82030.0      NaN                  754.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                  1158.0             NaN            442.0
# 2                   453.0             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                  1430.0           286.0              NaN
#
#    onVentilatorCurrently  ...  hospitalized   total totalTestResults  posNeg  \
# 0                    NaN  ...           NaN   23655            23655   23655
# 1                    NaN  ...        1158.0  109516           109516  109516
# 2                   14.0  ...         453.0   59003            59003   59003
# 3                    NaN  ...           NaN      83               83      83
# 4                  193.0  ...        1430.0   91737            91737   91737
#
#   fips deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 0   02           1.0                   0.0             962.0
# 1   01          27.0                  51.0            2454.0
# 2   05           5.0                   0.0            4296.0
# 3   60           0.0                   0.0               0.0
# 4   04          31.0                  33.0            3075.0
#
#    positiveIncrease  totalTestResultsIncrease
# 0               1.0                     963.0
# 1             296.0                    2750.0
# 2              72.0                    4368.0
# 3               0.0                       0.0
# 4             402.0                    3477.0
#
# [5 rows x 27 columns]

# %%
covid.shape
# Out:
# (3489, 27)

# %%
covid.to_csv('covid-daily.csv', index=False)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3489 entries, 0 to 3488
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      3489 non-null   int64
#  1   state                     3489 non-null   object
#  2   positive                  3474 non-null   float64
#  3   negative                  3307 non-null   float64
#  4   pending                   695 non-null    float64
#  5   hospitalizedCurrently     1311 non-null   float64
#  6   hospitalizedCumulative    1335 non-null   float64
#  7   inIcuCurrently            662 non-null    float64
#  8   inIcuCumulative           259 non-null    float64
#  9   onVentilatorCurrently     527 non-null    float64
#  10  onVentilatorCumulative    82 non-null     float64
#  11  recovered                 1158 non-null   float64
#  12  dataQualityGrade          672 non-null    object
#  13  lastUpdateEt              3116 non-null   object
#  14  hash                      3489 non-null   object
#  15  dateChecked               3489 non-null   object
#  16  death                     2762 non-null   float64
#  17  hospitalized              1335 non-null   float64
#  18  total                     3489 non-null   int64
#  19  totalTestResults          3489 non-null   int64
#  20  posNeg                    3489 non-null   int64
#  21  fips                      3489 non-null   object
#  22  deathIncrease             3433 non-null   float64
#  23  hospitalizedIncrease      3433 non-null   float64
#  24  negativeIncrease          3433 non-null   float64
#  25  positiveIncrease          3433 non-null   float64
#  26  totalTestResultsIncrease  3433 non-null   float64
# dtypes: float64(17), int64(4), object(6)
# memory usage: 736.1+ KB

# %%
list(covid.columns)
# Out:
# ['date',
#  'state',
#  'positive',
#  'negative',
#  'pending',
#  'hospitalizedCurrently',
#  'hospitalizedCumulative',
#  'inIcuCurrently',
#  'inIcuCumulative',
#  'onVentilatorCurrently',
#  'onVentilatorCumulative',
#  'recovered',
#  'dataQualityGrade',
#  'lastUpdateEt',
#  'hash',
#  'dateChecked',
#  'death',
#  'hospitalized',
#  'total',
#  'totalTestResults',
#  'posNeg',
#  'fips',
#  'deathIncrease',
#  'hospitalizedIncrease',
#  'negativeIncrease',
#  'positiveIncrease',
#  'totalTestResultsIncrease']

# %%
covid['positive'].plot()
