# %%
import requests
import pandas as pd

# %%
url = 'https://covidtracking.com/api/v1/states/daily.json'

# %%
req = requests.get(url)
req.status_code
# Out:
# 200

# %%
covid = req.json()

# %%
covid = pd.DataFrame(covid)

# %%
covid.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200511    AK     381.0   28299.0      NaN                    7.0
# 1  20200511    AL   10009.0  119435.0      NaN                    NaN
# 2  20200511    AR    4034.0   64996.0      NaN                   61.0
# 3  20200511    AS       0.0     105.0      NaN                    NaN
# 4  20200511    AZ   11380.0  138861.0      NaN                  717.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                  1256.0             NaN            463.0
# 2                   480.0             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                  1537.0           297.0              NaN
#
#    onVentilatorCurrently  ...  hospitalized   total totalTestResults  posNeg  \
# 0                    NaN  ...           NaN   28680            28680   28680
# 1                    NaN  ...        1256.0  129444           129444  129444
# 2                   11.0  ...         480.0   69030            69030   69030
# 3                    NaN  ...           NaN     105              105     105
# 4                  201.0  ...        1537.0  150241           150241  150241
#
#   fips deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 0   02           0.0                   0.0            1314.0
# 1   01           8.0                  16.0            1791.0
# 2   05           6.0                   9.0            3215.0
# 3   60           0.0                   0.0              22.0
# 4   04           6.0                   9.0           12241.0
#
#    positiveIncrease  totalTestResultsIncrease
# 0               2.0                    1316.0
# 1             232.0                    2023.0
# 2             287.0                    3502.0
# 3               0.0                      22.0
# 4             261.0                   12502.0
#
# [5 rows x 27 columns]

# %%
covid.shape
# Out:
# (3769, 27)

# %%
covid.to_csv('covid-daily.csv', index=False)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3769 entries, 0 to 3768
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      3769 non-null   int64
#  1   state                     3769 non-null   object
#  2   positive                  3754 non-null   float64
#  3   negative                  3582 non-null   float64
#  4   pending                   724 non-null    float64
#  5   hospitalizedCurrently     1520 non-null   float64
#  6   hospitalizedCumulative    1500 non-null   float64
#  7   inIcuCurrently            779 non-null    float64
#  8   inIcuCumulative           313 non-null    float64
#  9   onVentilatorCurrently     627 non-null    float64
#  10  onVentilatorCumulative    102 non-null    float64
#  11  recovered                 1366 non-null   float64
#  12  dataQualityGrade          949 non-null    object
#  13  lastUpdateEt              3396 non-null   object
#  14  hash                      3769 non-null   object
#  15  dateChecked               3769 non-null   object
#  16  death                     3043 non-null   float64
#  17  hospitalized              1500 non-null   float64
#  18  total                     3769 non-null   int64
#  19  totalTestResults          3769 non-null   int64
#  20  posNeg                    3769 non-null   int64
#  21  fips                      3769 non-null   object
#  22  deathIncrease             3713 non-null   float64
#  23  hospitalizedIncrease      3713 non-null   float64
#  24  negativeIncrease          3713 non-null   float64
#  25  positiveIncrease          3713 non-null   float64
#  26  totalTestResultsIncrease  3713 non-null   float64
# dtypes: float64(17), int64(4), object(6)
# memory usage: 795.1+ KB

# %%
list(covid.columns)
# Out:
# ['date',
#  'state',
#  'positive',
#  'negative',
#  'pending',
#  'hospitalizedCurrently',
#  'hospitalizedCumulative',
#  'inIcuCurrently',
#  'inIcuCumulative',
#  'onVentilatorCurrently',
#  'onVentilatorCumulative',
#  'recovered',
#  'dataQualityGrade',
#  'lastUpdateEt',
#  'hash',
#  'dateChecked',
#  'death',
#  'hospitalized',
#  'total',
#  'totalTestResults',
#  'posNeg',
#  'fips',
#  'deathIncrease',
#  'hospitalizedIncrease',
#  'negativeIncrease',
#  'positiveIncrease',
#  'totalTestResultsIncrease']

# %%
covid['positive'].plot()
